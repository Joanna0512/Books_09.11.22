# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Book_Dataset_1.csv', index_col='Title')

# %%
df.head(10)
# Out:
#                                                     Unnamed: 0  \
# Title
# A Light in the Attic                                         0
# Tipping the Velvet                                           1
# Soumission                                                   2
# Sharp Objects                                                3
# Sapiens: A Brief History of Humankind                        4
# The Requiem Red                                              5
# The Dirty Little Secrets of Getting Your Dream Job           6
# The Coming Woman: A Novel Based on the Life of ...           7
# The Boys in the Boat: Nine Americans and Their ...           8
# The Black Maria                                              9
#
#                                                               Category  Price  \
# Title
# A Light in the Attic                                            Poetry  51.77
# Tipping the Velvet                                  Historical Fiction  53.74
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, A Light in the Attic to 1,000 Places to See Before You Die
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1000 non-null   int64
#  1   Category           1000 non-null   object
#  2   Price              1000 non-null   float64
#  3   Price_After_Tax    1000 non-null   float64
#  4   Tax_amount         1000 non-null   float64
#  5   Avilability        1000 non-null   int64
#  6   Number_of_reviews  1000 non-null   int64
#  7   Book_Description   1000 non-null   object
#  8   Image_Link         1000 non-null   object
#  9   Stars              1000 non-null   int64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 118.2+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0       Price  Price_After_Tax  Tax_amount  Avilability  \
# count  1000.000000  1000.00000       1000.00000      1000.0  1000.000000
# mean    499.500000    35.07035         35.07035         0.0     8.585000
# std     288.819436    14.44669         14.44669         0.0     5.654622
# min       0.000000    10.00000         10.00000         0.0     1.000000
# 25%     249.750000    22.10750         22.10750         0.0     3.000000
# 50%     499.500000    35.98000         35.98000         0.0     7.000000
# 75%     749.250000    47.45750         47.45750         0.0    14.000000
# max     999.000000    59.99000         59.99000         0.0    22.000000
#
#        Number_of_reviews        Stars
# count             1000.0  1000.000000
# mean                 0.0     2.923000
# std                  0.0     1.434967
# min                  0.0     1.000000
# 25%                  0.0     2.000000
# 50%                  0.0     3.000000
# 75%                  0.0     4.000000
# ...

# %% [markdown]
# Całkowity brak podatku, można usunąć kolumnę, to samo w przypadku kolumny number of reviews
